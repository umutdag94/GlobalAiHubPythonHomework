# %%
studentName="Umut"
studentSurname="Dağ"
counter=1
while counter < 4:
    student_name =input("Please enter your name:")
    student_surname= input("Please enter your surname:")
    if (student_name != studentName and student_surname!= studentSurname ):
        print("Name & Surname Error, please try again")
        counter+=1
    elif (student_name == studentName and student_surname!= studentSurname):
        print("Surname Error, please try again")
        counter+=1
    elif (student_name != studentName and student_surname== studentSurname):
        print("Name Error, please try again.")
        counter+=1
    else: 
        print("Welcome ", studentName)
        counter=5
        A=1
    if counter==4 :
        print("Please try again later")
        A=0
           
if A ==1:
    print ("Time to select Courses")
    def return_failed() :
                    return " You failed in the class"
    Courses = ["ENG","MATH","CHE","PHY","STAT"]
    Selected_Courses =[]
    
    print (Courses)
    x=1
    y=0
    while (x < 4) and (y<4):
        
        student_course= input("Please select your courses one by one, minimum 3 and maksimum 5 ")
        if student_course in Courses:
            Selected_Courses. append(student_course)
            print (Selected_Courses)
            print ( " Great you have chosen ",len (Selected_Courses), "course/s")   
            x+=1
        else:
            print (" Please enter a course from available courses, you have only 4 mistake right")
            y+=1
        if y==4:
            print (return_failed())
   
    while (3<x<=5):
        
        print (" You have right to choose between 3 to 5 courses , pls write correct names of remaining courses")
        decision= input (" Do you want add course/s more; if yes type YES , if no type NO:")
                        
        # I assume that the student writes correct courses from remaining so i didn't use some controls
        if decision== "YES":
            student_course= input("Please select your course ")
            if student_course in Courses:
                Selected_Courses. append(student_course)
                print (Selected_Courses)
                print ( " Great you have chosen ",len (Selected_Courses), "course/s")   
                x+=1
        else:
            X+=2
            print ("Time to Exams")
            break
    if y!=4:
        print ( "You selected ", Selected_Courses, "courses")
    
        exam_course= input ("Select one of the course for exams:")# I assume that the student writes correct name of course

        print ("You entered exams for  :", exam_course, "course", "and you got grades below")
    
        exam_results={"midterm":int(20), "final":int(30), "project":int(10)}    
   
        a=exam_results.get("midterm")
        b=exam_results.get("final")
        c=exam_results.get("project")

        final_grades=(a*30+b*50+c*20)/100
    
        print ( "The weights of exams are respectively as 30% of midterm, 50% of final and 20% of project")
    
        print (studentName," your term grades after calculation is:", final_grades)
        if (final_grades)>90:
            print ( "Congrats you passed by getting AA")
        elif 70<(final_grades)<=90:  # there was no comment about for the cases 90, 70 etc i added equality
            print ( "Congrats you passed by getting BB")
        elif 50<(final_grades)<=70:  
            print ( "Congrats you passed by getting CC")
        elif 30<(final_grades)<=50: 
            print ( "Congrats you passed by getting DD")
        else :
            print (" Sorry, you got FF and you failed")
